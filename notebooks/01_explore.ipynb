# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %%
import sys
import pandas as pd

sys.path.append('../src')

from ingest import load_raw_data

# %%
df = load_raw_data() # print number of rows and columns
# Out:
# Loaded 5268 rows and 14 columns

# %%
df['Date'].head()
# Out:
# 0    09/17/1908
# 1    07/12/1912
# 2    08/06/1913
# 3    09/09/1913
# 4    10/17/1913
# Name: Date, dtype: str

# %%
df.head() # first five rows of the dataframe
# Out:
#    index        Date   Time                            Location  \
# 0      0  09/17/1908  17:18                 Fort Myer, Virginia
# 1      1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2      2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3      3  09/09/1913  18:30                  Over the North Sea
# 4      4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# ...

# %%
df.isnull().sum() # check for missing values in each column
# Out:
# index              0
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1707
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
df.dtypes # check the data types of each column
# Out:
# index             int64
# Date                str
# Time                str
# Location            str
# Operator            str
# Flight #            str
# Route               str
# Type                str
# Registration        str
# cn/In               str
# Aboard          float64
# Fatalities      float64
# Ground          float64
# Summary             str
# dtype: object

# %%
for i, summary in enumerate(df['Summary'].dropna().sample(15, random_state=42)):
    print(f"{i+1}. {summary}\n") # prints 15 random summary rows from summary columns, and drops any null values in the summary
# Out:
# 1. The plane crashed in unstable weather while en route from Manshahr to Tehran.
#
# 2. Crashed while attempting to land in crosswinds and high seas.
#
# 3. Flew into a hillside soon after takeoff from Kisumu. The ship was named 'Amalthea.'
#
# 4. Crashed 3 km short of the runway into a snow bank. Disintegration of the No. 1 engine turbine wheel.
#
# 5. Crashed into dense jungle, 4 miles short of its destination in heavy fog.
#
# 6. The leased aircraft was shot down by UNITA rebels as it flew at FL 150 carrying relief supplies.
#
# 7. The aircraft, during a training flight suddenly rolled to the left and  crashed after a missed, 3 engine, ILS approach. Failure of the aircraft rudder hydrauliactuator support fitting which led to the loss of left rudder control. Stress corrosion cracks.
#
# 8. Crashed while on approach to Lyons.
#
# 9. Two phosphorus bombs were thrown into the aircraft prior to its departure. The aircraft was named 'Clipper Celestial.'
#
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%m/%d/%y', errors='coerce') # convert the date column to datetime format, and coerce any errors to NaT

# %%
df_clean = pd.read_csv("../data/clean/airplane_crashes_clean.csv")
df_clean.dtypes
# Out:
# Date              str
# Location          str
# Operator          str
# Type              str
# Aboard        float64
# Fatalities    float64
# Ground        float64
# Summary           str
# dtype: object

# %%
df_clean['Date'].head()
# Out:
# 0    1908-09-17
# 1    1912-07-12
# 2    1913-08-06
# 3    1913-09-09
# 4    1913-10-17
# Name: Date, dtype: str

# %%
df = pd.read_csv("../data/final/airplane_crashes_classified.csv")

# %%
other_sample = df[df['cause_category'] == 'Other']['Summary'].sample(15, random_state=1)
for i, s in enumerate(other_sample):
    print(f"{i+1}. {s}\n")
# Out:
# 1. Crashed in the Tapecua mountains.
#
# 2. Crashed shortly after taking off from Bogata.
#
# 3. In-flight separation of a main rotor blade due to fatigue failure of the main rotor blade spar, which originated at a manufacturing induced scratch (tool mark) that was the result of inadequate quality control.
#
# 4. Both engines failed and the plane ditched 1 mile offshore and sank.
#
# 5. Crashed into approach lights while attempting to land.  Error of judgement on the part of the pilot.
#
# ...

# %%
pe_sample = df[df['cause_category'] == 'Pilot Error']['Summary'].sample(10, random_state=1)
for i, s in enumerate(pe_sample):
    print(f"{i+1}. {s}\n")
# Out:
# 1. Made a forced landing in water. Fuel starvation. Inattentiveness to fuel supply. Fuel selector positioned between tanks.
#
# 2. The pilot asked for clearance to make a low pass over Mokmer to give the passengers a final glimpse of the island. The plane gradually descended over the sea, crashed, burst into flames, broke apart and sank. Crew did not properly monitor their altitude.
#
# 3. During a steep climb at an airshow, the airplane was observed to level off very abruptly and then begin a dive. The plane broke apart and exploded before crashing into a residential area killing 8 people and seriously injuring 60 others. The pilot, possibly startled by a close encounter with a Mirage jet photographing the TU-144, overreacted causing a compressor stall. The aircraft then went into a dive and broke apart after the aircraft's design capacity was exceeded.
#
# ...
